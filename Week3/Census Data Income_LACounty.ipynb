# %%
print('Income for census tracts in LA County. Will look at census tracts that are lower income.')
# Out:
# Income for census tracts in LA County. Will look at census tracts that are lower income.

# %%
import pandas as pd
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt

# %%
gdf = gpd.read_file('Data/Census_Data/acs2019_5yr_B19001_14000US06037534001.geojson')

# %%
gdf.head()
# Out:
#                 geoid                                   name  B19001001  \
# 0        05000US06037                 Los Angeles County, CA  3316795.0
# 1  14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1575.0
# 2  14000US06037101122  Census Tract 1011.22, Los Angeles, CA     1312.0
# 3  14000US06037101210  Census Tract 1012.10, Los Angeles, CA     2297.0
# 4  14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1357.0
#
#    B19001001, Error  B19001002  B19001002, Error  B19001003  B19001003, Error  \
# 0            5782.0   185622.0            3065.0   157633.0            2635.0
# 1              90.0       86.0              71.0       91.0              65.0
# 2              63.0       66.0              52.0       21.0              22.0
# 3              98.0      271.0             127.0      135.0              69.0
# 4              57.0       85.0              53.0      128.0              59.0
#
# ...

# %%
print('practice map')
# Out:
# practice map

# %%
gdf.plot(figsize=(10,10))

# %%
gdf.sample()
# Out:
#                    geoid                                name  B19001001  \
# 1538  14000US06037530700  Census Tract 5307, Los Angeles, CA      547.0
#
#       B19001001, Error  B19001002  B19001002, Error  B19001003  \
# 1538              35.0        6.0               9.0       13.0
#
#       B19001003, Error  B19001004  B19001004, Error  ...  B19001013, Error  \
# 1538              16.0       13.0              15.0  ...              44.0
#
#       B19001014  B19001014, Error  B19001015  B19001015, Error  B19001016  \
# 1538       72.0              37.0       13.0              12.0       20.0
#
#       B19001016, Error  B19001017  B19001017, Error  \
# 1538              20.0        5.0               8.0
#
#                                                geometry
# 1538  MULTIPOLYGON (((-118.19263 34.06176, -118.1925...
#
# [1 rows x 37 columns]

# %%
gdf.geoid.head()
# Out:
# 0          05000US06037
# 1    14000US06037101110
# 2    14000US06037101122
# 3    14000US06037101210
# 4    14000US06037101220
# Name: geoid, dtype: object

# %%
gdf.head()
# Out:
#                 geoid                                   name  B19001001  \
# 0        05000US06037                 Los Angeles County, CA  3316795.0
# 1  14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1575.0
# 2  14000US06037101122  Census Tract 1011.22, Los Angeles, CA     1312.0
# 3  14000US06037101210  Census Tract 1012.10, Los Angeles, CA     2297.0
# 4  14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1357.0
#
#    B19001001, Error  B19001002  B19001002, Error  B19001003  B19001003, Error  \
# 0            5782.0   185622.0            3065.0   157633.0            2635.0
# 1              90.0       86.0              71.0       91.0              65.0
# 2              63.0       66.0              52.0       21.0              22.0
# 3              98.0      271.0             127.0      135.0              69.0
# 4              57.0       85.0              53.0      128.0              59.0
#
# ...

# %%
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'B19001001',
#  'B19001001, Error',
#  'B19001002',
#  'B19001002, Error',
#  'B19001003',
#  'B19001003, Error',
#  'B19001004',
#  'B19001004, Error',
#  'B19001005',
#  'B19001005, Error',
#  'B19001006',
#  'B19001006, Error',
#  'B19001007',
#  'B19001007, Error',
#  'B19001008',
#  'B19001008, Error',
#  'B19001009',
#  'B19001009, Error',
#  'B19001010',
#  'B19001010, Error',
#  'B19001011',
#  'B19001011, Error',
#  'B19001012',
#  'B19001012, Error',
#  'B19001013',
#  'B19001013, Error',
#  'B19001014',
#  'B19001014, Error',
#  'B19001015',
#  'B19001015, Error',
#  'B19001016',
#  'B19001016, Error',
#  'B19001017',
#  'B19001017, Error',
#  'geometry']

# %%
print('keeping lower-income census tracts')
# Out:
# keeping lower-income census tracts

# %%
columns_to_keep = ['geoid',
    'name',
    'B19001001',
    'B19001002',
    'B19001003',
    'B19001004',
    'B19001005',
    'B19001006',
    'B19001007',
    'B19001008',
    'B19001009',
    'B19001010',
    'B19001011',
    'B19001012',
    'geometry']

# %%
gdf = gdf[columns_to_keep]

# %%
gdf.head()
# Out:
#                 geoid                                   name  B19001001  \
# 0        05000US06037                 Los Angeles County, CA  3316795.0
# 1  14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1575.0
# 2  14000US06037101122  Census Tract 1011.22, Los Angeles, CA     1312.0
# 3  14000US06037101210  Census Tract 1012.10, Los Angeles, CA     2297.0
# 4  14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1357.0
#
#    B19001002  B19001003  B19001004  B19001005  B19001006  B19001007  \
# 0   185622.0   157633.0   135556.0   142811.0   129873.0   138123.0
# 1       86.0       91.0      101.0       44.0       55.0       78.0
# 2       66.0       21.0        0.0       47.0       36.0       25.0
# 3      271.0      135.0      278.0       39.0      108.0      169.0
# 4       85.0      128.0      124.0       57.0       35.0       94.0
#
#    B19001008  B19001009  B19001010  B19001011  B19001012  \
# 0   126853.0   127576.0   116721.0   225974.0   300644.0
# ...

# %%
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'B19001001',
#  'B19001002',
#  'B19001003',
#  'B19001004',
#  'B19001005',
#  'B19001006',
#  'B19001007',
#  'B19001008',
#  'B19001009',
#  'B19001010',
#  'B19001011',
#  'B19001012',
#  'geometry']

# %%
print('renaming census tracts to match income range')
# Out:
# renaming census tracts to match income range

# %%
gdf.columns = ['geoid',
              'name',
              'total',
              'Less than $10,000',
              '$10,000 to $14,999',
              '$15,000 to $19,999',
              '$20,000 to $24,999',
              '$25,000 to $29,999',
              '$30,000 to $34,999',
              '$35,000 to $39,999',
              '$40,000 to $44,999',
              '$45,000 to $49,999',
              '$50,000 to $59,999',
              '$60,000 to $74,999',
              'geometry']

# %%
gdf.head()
# Out:
#                 geoid                                   name      total  \
# 0        05000US06037                 Los Angeles County, CA  3316795.0
# 1  14000US06037101110  Census Tract 1011.10, Los Angeles, CA     1575.0
# 2  14000US06037101122  Census Tract 1011.22, Los Angeles, CA     1312.0
# 3  14000US06037101210  Census Tract 1012.10, Los Angeles, CA     2297.0
# 4  14000US06037101220  Census Tract 1012.20, Los Angeles, CA     1357.0
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 0           185622.0            157633.0            135556.0
# 1               86.0                91.0               101.0
# 2               66.0                21.0                 0.0
# 3              271.0               135.0               278.0
# 4               85.0               128.0               124.0
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 0            142811.0            129873.0            138123.0
# ...

# %%
gdf = gdf.drop([0])

# %%
gdf.head()
# Out:
#                 geoid                                   name   total  \
# 1  14000US06037101110  Census Tract 1011.10, Los Angeles, CA  1575.0
# 2  14000US06037101122  Census Tract 1011.22, Los Angeles, CA  1312.0
# 3  14000US06037101210  Census Tract 1012.10, Los Angeles, CA  2297.0
# 4  14000US06037101220  Census Tract 1012.20, Los Angeles, CA  1357.0
# 5  14000US06037101300     Census Tract 1013, Los Angeles, CA  1445.0
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 1               86.0                91.0               101.0
# 2               66.0                21.0                 0.0
# 3              271.0               135.0               278.0
# 4               85.0               128.0               124.0
# 5               78.0                18.0                59.0
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 1                44.0                55.0                78.0
# ...

# %%
print('histogram distribution of income in LA County')
# Out:
# histogram distribution of income in LA County

# %%
gdf['total'].plot.hist(bins=50)

# %%
gdf['total'].median()
# Out:
# 1339.0

# %%
gdf['total'].describe()
# Out:
# count    2346.000000
# mean     1413.808610
# std       616.966186
# min         0.000000
# 25%      1011.250000
# 50%      1339.000000
# 75%      1728.000000
# max      5663.000000
# Name: total, dtype: float64

# %%
gdf[gdf['total']==0]
# Out:
#                    geoid                                   name  total  \
# 848   14000US06037265301  Census Tract 2653.01, Los Angeles, CA    0.0
# 1055  14000US06037320000     Census Tract 3200, Los Angeles, CA    0.0
# 1123  14000US06037403200     Census Tract 4032, Los Angeles, CA    0.0
# 1747  14000US06037551600     Census Tract 5516, Los Angeles, CA    0.0
# 1890  14000US06037574601  Census Tract 5746.01, Los Angeles, CA    0.0
# 1892  14000US06037574700     Census Tract 5747, Los Angeles, CA    0.0
# 2197  14000US06037901003  Census Tract 9010.03, Los Angeles, CA    0.0
# 2298  14000US06037920200     Census Tract 9202, Los Angeles, CA    0.0
# 2318  14000US06037980001  Census Tract 9800.01, Los Angeles, CA    0.0
# 2319  14000US06037980002  Census Tract 9800.02, Los Angeles, CA    0.0
# 2320  14000US06037980003  Census Tract 9800.03, Los Angeles, CA    0.0
# 2321  14000US06037980004  Census Tract 9800.04, Los Angeles, CA    0.0
# ...

# %%
print('identifying census tracts with zero values.')
# Out:
# identifying census tracts with zero values.

# %%
gdf_no_pop = gdf[gdf['total']==0]

# %%
print('There are ' + str(len(gdf_no_pop)) + ' census tracts with no people in them')
# Out:
# There are 27 census tracts with no people in them

# %%
list(gdf)
# Out:
# ['geoid',
#  'name',
#  'total',
#  'Less than $10,000',
#  '$10,000 to $14,999',
#  '$15,000 to $19,999',
#  '$20,000 to $24,999',
#  '$25,000 to $29,999',
#  '$30,000 to $34,999',
#  '$35,000 to $39,999',
#  '$40,000 to $44,999',
#  '$45,000 to $49,999',
#  '$50,000 to $59,999',
#  '$60,000 to $74,999',
#  'geometry']

# %%
print('creating percent categories')
# Out:
# creating percent categories

# %%
gdf['Percent Less than $10,000'] + gdf['Percent $10,000 to $14,999'] + gdf['Percent $15,000 to $19,999'] + gdf['Percent $20,000 to $24,999']
# Out:
# 1        20.444444
# 2        10.213415
# 3        31.475838
# 4        29.034635
# 5        13.010381
#            ...
# 2342      0.000000
# 2343    100.000000
# 2344           NaN
# 2345           NaN
# 2346           NaN
# Length: 2346, dtype: float64

# %%
gdf.sample(5)
# Out:
#                    geoid                                   name   total  \
# 1766  14000US06037553300     Census Tract 5533, Los Angeles, CA   989.0
# 1975  14000US06037601700     Census Tract 6017, Los Angeles, CA  1303.0
# 844   14000US06037264302  Census Tract 2643.02, Los Angeles, CA  2962.0
# 1870  14000US06037573003  Census Tract 5730.03, Los Angeles, CA   622.0
# 1745  14000US06037551501  Census Tract 5515.01, Los Angeles, CA  1425.0
#
#       Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 1766               79.0                38.0                43.0
# 1975               58.0                55.0                47.0
# 844               272.0                25.0               100.0
# 1870               33.0                14.0                30.0
# 1745                7.0                33.0                60.0
#
#       $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 1766                73.0                70.0                73.0
# ...

# %%
print('adding a new category combining the four lowest income categories together. I modelled the category after poverty levels of income of a family of three.')
# Out:
# adding a new category combining the four lowest income categories together. I modelled the category after poverty levels of income of a family of three.

# %%
gdf['Percent Poverty'] = gdf['Percent Less than $10,000'] + gdf['Percent $10,000 to $14,999'] + gdf['Percent $15,000 to $19,999'] + gdf['Percent $20,000 to $24,999']

# %%
gdf.sample(5)
# Out:
#                    geoid                                   name   total  \
# 680   14000US06037221601  Census Tract 2216.01, Los Angeles, CA   954.0
# 1726  14000US06037550201  Census Tract 5502.01, Los Angeles, CA   769.0
# 618   14000US06037213202  Census Tract 2132.02, Los Angeles, CA  1287.0
# 1122  14000US06037403000     Census Tract 4030, Los Angeles, CA  1516.0
# 1154  14000US06037403901  Census Tract 4039.01, Los Angeles, CA   911.0
#
#       Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 680                94.0                90.0                64.0
# 1726               28.0                30.0                13.0
# 618                90.0               138.0               131.0
# 1122               64.0                26.0                36.0
# 1154               26.0                21.0                25.0
#
#       $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 680                 52.0                63.0                70.0
# ...

# %%
print('map of census tracts percentage of poverty')
# Out:
# map of census tracts percentage of poverty

# %%
gdf.plot(figsize=(12,10),
                 column='Percent Poverty',
                 legend=True, 
                 cmap='RdPu',
                 scheme='NaturalBreaks')

# %%
gdf[gdf['Percent Poverty'] > 25]
# Out:
#                    geoid                                   name   total  \
# 3     14000US06037101210  Census Tract 1012.10, Los Angeles, CA  2297.0
# 4     14000US06037101220  Census Tract 1012.20, Los Angeles, CA  1357.0
# 21    14000US06037104203  Census Tract 1042.03, Los Angeles, CA  1169.0
# 31    14000US06037104701  Census Tract 1047.01, Los Angeles, CA   926.0
# 32    14000US06037104703  Census Tract 1047.03, Los Angeles, CA   572.0
# ...                  ...                                    ...     ...
# 2228  14000US06037910502  Census Tract 9105.02, Los Angeles, CA  1181.0
# 2232  14000US06037910602  Census Tract 9106.02, Los Angeles, CA  1357.0
# 2307  14000US06037920330  Census Tract 9203.30, Los Angeles, CA  1538.0
# 2327  14000US06037980010  Census Tract 9800.10, Los Angeles, CA    56.0
# 2343  14000US06037980033  Census Tract 9800.33, Los Angeles, CA    16.0
#
#       Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# ...

# %%
print('map of census tracts where at least 1/3 of people are making $24,999 or less')
# Out:
# map of census tracts where at least 1/3 of people are making $24,999 or less

# %%
gdf[gdf['Percent Poverty'] > 33.3].plot(figsize=(12,10))

# %%
gdf_web_mercator = gdf.to_crs(epsg=3857)

# %%
gdf_web_mercator.head()
# Out:
#                 geoid                                   name   total  \
# 1  14000US06037101110  Census Tract 1011.10, Los Angeles, CA  1575.0
# 2  14000US06037101122  Census Tract 1011.22, Los Angeles, CA  1312.0
# 3  14000US06037101210  Census Tract 1012.10, Los Angeles, CA  2297.0
# 4  14000US06037101220  Census Tract 1012.20, Los Angeles, CA  1357.0
# 5  14000US06037101300     Census Tract 1013, Los Angeles, CA  1445.0
#
#    Less than $10,000  $10,000 to $14,999  $15,000 to $19,999  \
# 1               86.0                91.0               101.0
# 2               66.0                21.0                 0.0
# 3              271.0               135.0               278.0
# 4               85.0               128.0               124.0
# 5               78.0                18.0                59.0
#
#    $20,000 to $24,999  $25,000 to $29,999  $30,000 to $34,999  \
# 1                44.0                55.0                78.0
# ...

# %%
print('map of census tracts where at least 1/3 of people are making $24,999 or less with basemap')
# Out:
# map of census tracts where at least 1/3 of people are making $24,999 or less with basemap

# %%
fig, ax = plt.subplots(figsize=(15, 15))
gdf_web_mercator[gdf_web_mercator['Percent Poverty'] > 33.3].plot(ax=ax, alpha=0.8)
ax.axis('off')
ax.set_title('Census Tracts with more than 33% of People Living in Poverty (Less than $24,999 for a Household of Three)',fontsize=24)
ctx.add_basemap(ax)
